# %% [markdown]
# # Stock Prices

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd 
import numpy as np
import altair as alt

df = pd.read_csv("AAPL (3).csv")

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2000-01-03    0.936384    1.004464    0.907924    0.999442    0.850644
# 1     2000-01-04    0.966518    0.987723    0.903460    0.915179    0.778926
# 2     2000-01-05    0.926339    0.987165    0.919643    0.928571    0.790324
# 3     2000-01-06    0.947545    0.955357    0.848214    0.848214    0.721930
# 4     2000-01-07    0.861607    0.901786    0.852679    0.888393    0.756128
# ...          ...         ...         ...         ...         ...         ...
# 5865  2023-04-26  163.059998  165.279999  162.800003  163.759995  163.759995
# 5866  2023-04-27  165.190002  168.559998  165.190002  168.410004  168.410004
# 5867  2023-04-28  168.490005  169.850006  167.880005  169.679993  169.679993
# 5868  2023-05-01  169.279999  170.449997  168.639999  169.589996  169.589996
# 5869  2023-05-02  170.089996  170.350006  167.539993  168.539993  168.539993
#
#          Volume
# 0     535796800
# ...

# %% [markdown]
# # Interest Rates

# %%
df2 = pd.read_csv("Monthly.csv")

# %%
df2
# Out:
#            DATE  INTDSRUSM193N
# 0    2000-01-01           5.00
# 1    2000-02-01           5.24
# 2    2000-03-01           5.34
# 3    2000-04-01           5.50
# 4    2000-05-01           5.71
# ..          ...            ...
# 255  2021-04-01           0.25
# 256  2021-05-01           0.25
# 257  2021-06-01           0.25
# 258  2021-07-01           0.25
# 259  2021-08-01           0.25
#
# [260 rows x 2 columns]

# %%
alt.Chart(df2).mark_point().encode(
    x='DATE',
    y='INTDSRUSM193N'
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# # Rev by Product

# %%
df3 = pd.read_csv("AAPLunitsQ214_cumLaunch.csv")

# %%
df3
# Out:
#       Year  iphone    ipad    ipod  Acc iphone  Acc ipad  Acc ipod
# 0        0     0.0     0.0     NaN         0.0       0.0       NaN
# 1        1     1.4     7.5     NaN         1.4       7.5       NaN
# 2        2    11.6    32.4     NaN        13.0      39.9       NaN
# 3        3    20.7    58.3     NaN        33.7      98.2       NaN
# 4        4    40.0    71.1     NaN        73.7     169.3       NaN
# 5        5    72.3    42.4     NaN       146.0     211.7       NaN
# 6        6   125.0     NaN     7.1       271.0       NaN       7.1
# 7        7   150.2     NaN     9.7       421.2       NaN      16.8
# 8        8    94.7     NaN    10.4       515.9       NaN      27.2
# 9        9     NaN     NaN     NaN         NaN       NaN       NaN
# 10     NaN     NaN     NaN     NaN         NaN       NaN       NaN
# 11  Launch  2007.0  2010.0  2001.0         NaN       NaN       NaN

# %%
alt.Chart(df3).mark_point().encode(
    x='Year',
    y='iphone'
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# # FED FUND RATE

# %%
df4 = pd.read_csv("FEDFUNDS.csv")

# %%
df4
# Out:
#            DATE  FEDFUNDS
# 0    2000-01-01      5.45
# 1    2000-02-01      5.73
# 2    2000-03-01      5.85
# 3    2000-04-01      6.02
# 4    2000-05-01      6.27
# ..          ...       ...
# 275  2022-12-01      4.10
# 276  2023-01-01      4.33
# 277  2023-02-01      4.57
# 278  2023-03-01      4.65
# 279  2023-04-01      4.83
#
# [280 rows x 2 columns]

# %%
alt.Chart(df4).mark_point().encode(
    x='DATE',
    y='FEDFUNDS'
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# # Exchange Rate

# %%
df5 = pd.read_csv("euro-exchange-rates.csv")

# %%
df5
# Out:
#          Period;Currency;Rate
# 0      2003-07-30;MXN;12.0277
# 1       2003-08-01;SEK;9.2302
# 2       2003-08-05;CAD;1.5958
# 3       2003-08-12;SEK;9.2671
# 4       2003-08-14;SEK;9.2273
# ...                       ...
# 52765   2017-04-06;GBP;0.8559
# 52766   2017-04-11;GBP;0.8533
# 52767   2017-04-21;USD;1.0698
# 52768   2017-04-25;AUD;1.4454
# 52769    2017-05-10;SEK;9.699
#
# [52770 rows x 1 columns]
